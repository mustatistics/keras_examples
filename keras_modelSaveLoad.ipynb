# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
#np.set_printoptions(suppress=True)

# %%
# Define Sequential model with 4 layers

model = keras.Sequential(
    [
        layers.Dense(8, activation="relu", input_dim=4),
        layers.Dense(16, activation="relu"),
        layers.Dense(8, activation="relu"),
        layers.Dense(1, activation="linear")
    ]
)

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
data = np.genfromtxt("fibos.txt", dtype='int', delimiter = ",")
data
# Out:
# array([[   1,    1,    2,    3,    5],
#        [   1,    2,    3,    5,    8],
#        [   2,    3,    5,    8,   13],
#        [   3,    5,    8,   13,   21],
#        [   5,    8,   13,   21,   34],
#        [   8,   13,   21,   34,   55],
#        [  13,   21,   34,   55,   89],
#        [  21,   34,   55,   89,  144],
#        [  34,   55,   89,  144,  233],
#        [  55,   89,  144,  233,  377],
#        [  89,  144,  233,  377,  610],
#        [ 144,  233,  377,  610,  987],
#        [ 233,  377,  610,  987, 1597],
#        [ 377,  610,  987, 1597, 2584],
#        [ 610,  987, 1597, 2584, 4181],
#        [ 987, 1597, 2584, 4181, 6765]])

# %%
X_train = data[:,:4]
y_train = data[:,4]

# %%
model.fit(
    X_train, 
    y_train,
    batch_size = 2,
    epochs = 200,
    verbose = 1,
    validation_split = 0.35
)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 29ms/step - loss: 34484.1875 - val_loss: 17983398.0000
# Epoch 2/200
# 5/5 [==============================] - 0s 6ms/step - loss: 33055.0547 - val_loss: 17445960.0000
# Epoch 3/200
# 5/5 [==============================] - 0s 5ms/step - loss: 32188.3965 - val_loss: 16927802.0000
# Epoch 4/200
# 5/5 [==============================] - 0s 5ms/step - loss: 31267.7441 - val_loss: 16590379.0000
# Epoch 5/200
# 5/5 [==============================] - 0s 5ms/step - loss: 30815.6523 - val_loss: 16191640.0000
# Epoch 6/200
# 5/5 [==============================] - 0s 5ms/step - loss: 30090.3848 - val_loss: 15818439.0000
# Epoch 7/200
# 5/5 [==============================] - 0s 6ms/step - loss: 29216.8242 - val_loss: 15499872.0000
# Epoch 8/200
# 5/5 [==============================] - 0s 6ms/step - loss: 28692.4648 - val_loss: 15153597.0000
# Epoch 9/200
# ...

# %%
# Test
X_test = np.array([
    [2584, 4181, 6765, 10946],
    [28657, 46368, 75025, 121393],
    [317811, 514229, 832040, 1346269]
])

y_test = np.array([
    [17711],
    [196418],
    [2178309]
])

output = model.evaluate(X_test, y_test)

print("")
print("=== Evaluation ===")
print(model.metrics_names)
print(output)
# Out:
# 1/1 [==============================] - 0s 142ms/step - loss: 37159980.0000
#
# === Evaluation ===
# ['loss']
# 37159980.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 40
#
#  dense_1 (Dense)             (None, 16)                144
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# ...
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_predict = np.array([
    [24157817, 39088169, 63245986, 102334155]
])#165580141

output = model.predict(x_predict)

print("")
print("Expected: 165580141")
print("Actual: ", output)
# Out:
# 1/1 [==============================] - 0s 85ms/step
#
# Expected: 165580141
# Actual:  [[1.6478074e+08]]

# %%
model.save('fibo.h5')

# %%
import numpy as np
from keras.models import load_model

model_loaded = load_model('fibo.h5')

#model_loaded.summary()

x_predict = np.array([
    [0,1,1,2]
])#3

output = model_loaded.predict(x_predict)

print("")
print("Expected: 3")
print("Actual: ", output)
# Out:
# 1/1 [==============================] - 0s 37ms/step
#
# Expected: 3
# Actual:  [[4.54581]]
